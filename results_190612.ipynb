# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import results as r
import numpy as np
from PIL import Image

# %%
location='/home/zenalisa/data/output/190612/250'
signal=location+'/signal.tiff'
target=location+'/target.tiff'
prediction=location+'/prediction_190611.tiff'

# %%
plot = r.display(signal, target, prediction)

# %%
target_path = '/home/zenalisa/data/output/190612/*/target.tiff'
signal_path = '/home/zenalisa/data/output/190612/*/signal.tiff'
prediction_path = '/home/zenalisa/data/output/190612/*/prediction_190611.tiff'
[ssim, mse]=r.ssim_mse(target_path, prediction_path)

# %%
import glob
r.best(ssim, mse, glob.glob(signal_path), glob.glob(target_path), glob.glob(prediction_path))
