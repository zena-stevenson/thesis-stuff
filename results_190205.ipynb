# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import results as r
import numpy as np
from PIL import Image

# %%
signal='/home/zenalisa/49/signal.tiff'
target='/home/zenalisa/49/target.tiff'
prediction='/home/zenalisa/49/prediction_190205.tiff'

# %%
plot = r.display(signal, target, prediction)

# %%
target_path = '/home/zenalisa/data/output/190208/*/target.tiff'
signal_path = '/home/zenalisa/data/output/190208/*/signal.tiff'
prediction_path = '/home/zenalisa/data/output/190208/*/prediction_190205.tiff'
[ssim, mse]=r.ssim_mse(target_path, prediction_path)

# %%
import glob
r.best(ssim, mse, glob.glob(signal_path), glob.glob(target_path), glob.glob(prediction_path))
